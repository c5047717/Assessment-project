# %% [markdown]
# # Full Project — AE Fixed

# %%
# !pip -q install -r requirements.txt

# %%
# !python -m src.pretrain_ae --config config.yaml --epochs 5

# %%
# !python -m src.train --config config.yaml

# %%
# !python -m src.eval --config config.yaml
